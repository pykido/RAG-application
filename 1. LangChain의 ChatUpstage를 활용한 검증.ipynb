# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-upstage
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. 환경변수 불러오기
#
# - `.env` 파일에 `OPENAI_API_KEY` 등록

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 3. LLM 답변 생성
#
# - Upstage Console에서 발급받은 API Key를 `UPSTAGE_API_KEY`라고 저장하면 별도의 설정 없이 `ChatUpstage`를 사용할 수 있음

# %%
from langchain_upstage import ChatUpstage

llm = ChatUpstage()

# %%
ai_message = llm.invoke("직선을 짧게 정의하라.")

# %%
ai_message.content
# Out:
# '직선은 두 점 사이의 가장 짧은 경로로 정의할 수 있습니다. 이는 두 지점 사이를 연결할 때 다른 어떤 곡선이나 곡면보다도 더 적은 거리를 이동하게 된다는 것을 의미합니다. 수학적으로, 직선은 모든 점이 하나의 일정한 거리(일반적으로 1)로 떨어져 있는 점들의 집합으로 정의할 수도 있습니다. 이러한 정의는 유클리드 기하학에서 흔히 사용되며, 직선의 기본적인 성질과 특성을 잘 포착하고 있습니다.'
